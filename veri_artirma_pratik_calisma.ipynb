# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
# !ls
# Out:
# MyDrive

# %%
# %cd /gdrive/MyDrive/veri-artirmak
# Out:
# /gdrive/MyDrive/veri-artirmak

# %%
# !ls
# Out:
# Artirilmis_veri  istanbul3.jpg	      veri_artirma_pratik_calisma.ipynb
# istanbul1.jpg	 veriArtirma_2.ipynb
# istanbul2.jpg	 veriArtirma.ipynb

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
datagen = ImageDataGenerator(channel_shift_range = 70,
                             zca_whitening=False,
                             horizontal_flip=True,
                             vertical_flip=True,
                             rescale=None,
                             fill_mode='reflect')

# %%
img = load_img('mavi_cat.jpg')
x = img_to_array(img)
x = x.reshape((1,)+x.shape)

# %%
i =0
for batch in datagen.flow(x, batch_size = 1,
                          save_to_dir='Artirilmis_veri',
                          save_format='jpeg'):
  
  i+=1
  if i>150:
    break
